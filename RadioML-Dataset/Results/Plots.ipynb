# %% [markdown]
# # Plots
#
# Plotting Results on Clean and Adversarial Data

# %% [markdown]
# ## Imports

# %% [markdown]
# ### Connecting to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My\ Drive/Modulation-Classification/RadioML-Dataset/Results
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/Modulation-Classification/RadioML-Dataset/Results

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import collections

# !pip3 install autokeras==1.0.12
# !pip3 install tensorflow==2.4
# !pip3 install keras-tuner==1.0.2
import autokeras as ak
import tensorflow as tf

from Plot_Results import *
from Plot_Confusion_Matrix import *
from Plot_AttackSuccess import *

# %% [markdown]
# ## Accuracy Plot of Clean Data

# %% [markdown]
# ### Importing Data

# %%
# Loading Validation Data
f = open("../Data/Clean-Data/Clean_X_Valid.pkl","rb")
Clean_X_Valid = pickle.load(f)

f = open("../Data/Clean-Data/Clean_y_Valid.pkl","rb")
Clean_y_Valid = pickle.load(f)

# %% [markdown]
# ### Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5")),
                    ("Clean", "Robust CNN Model", tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")),
                    ("Clean", "CLDNN Model", tf.keras.models.load_model("../Data/Model/Clean_CLDNN.h5")),
                    ("Clean", "ResNet Model", tf.keras.models.load_model("../Data/Model/Clean_ResNet.h5"))]

DataDescriptions = [("Clean", Clean_X_Valid, Clean_y_Valid)]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# Results on Clean Validation Dataset

# %%
Evaluate_Models_Datasets(ModelDescriptions, DataDescriptions, "AutoML_Models_Clean_Accuracy.png", (0,0.9125), ValidBatchSize=32)
# Out:
# Evaluating Models on Datasets
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Confusion-Matrices

# %% [markdown]
# ### Importing Data

# %%
# Loading Validation Data
f = open("../Data/Clean-Data/Clean_X_Valid.pkl","rb")
Clean_X_Valid = pickle.load(f)

f = open("../Data/Clean-Data/Clean_y_Valid.pkl","rb")
Clean_y_Valid = pickle.load(f)

f = open("../Data/Dataset/ModulationMap.pkl", "rb")
ModulationMap = pickle.load(f)

# %% [markdown]
# ### Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5"))]

DataDescriptions = [("Clean", Clean_X_Valid, Clean_y_Valid)]

# %% [markdown]
# Results on Clean Validation Dataset

# %%
Plot_Confusion_Matrices(ModelDescriptions, DataDescriptions, "Confusion-Matrices", ModulationMap, "Blues")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Accuracy Plot for PGD-Attack

# %% [markdown]
# ### Importing Data

# %% [markdown]
# Adversarial Data

# %%
# Loading Validation Data
f = open("../Data/PGD-Attack/Adversarial-Data-Valid/Adversarial_X_Valid.pkl","rb")
Adversarial_X_Valid = pickle.load(f)

f = open("../Data/PGD-Attack/Adversarial-Data-Valid/Adversarial_y_Valid.pkl","rb")
Adversarial_y_Valid = pickle.load(f)

# %% [markdown]
# ### Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5")),
                    ("Clean", "Robust CNN Model", tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")),
                    ("Clean", "CLDNN Model", tf.keras.models.load_model("../Data/Model/Clean_CLDNN.h5")),
                    ("Clean", "ResNet Model", tf.keras.models.load_model("../Data/Model/Clean_ResNet.h5"))]

DataDescriptions = [("Adversarial", Adversarial_X_Valid, Adversarial_y_Valid)]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# Results on Adversarial Validation Dataset

# %%
Evaluate_Models_Datasets(ModelDescriptions, DataDescriptions, "Models_PGD_Accuracy.png", (0,0.175 ), ValidBatchSize=32)
# Out:
# Evaluating Models on Datasets
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Accuracy Plot for CW-Attack

# %% [markdown]
# ### Importing Data

# %% [markdown]
# Adversarial Data

# %%
# Loading Validation Data
f = open("../Data/CW-Attack/Adversarial-Data-Valid/Adversarial_X_Valid.pkl","rb")
Adversarial_X_Valid = pickle.load(f)

f = open("../Data/CW-Attack/Adversarial-Data-Valid/Adversarial_y_Valid.pkl","rb")
Adversarial_y_Valid = pickle.load(f)

# %% [markdown]
# ### Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5")),
                    ("Clean", "Robust CNN Model", tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")),
                    ("Clean", "CLDNN Model", tf.keras.models.load_model("../Data/Model/Clean_CLDNN.h5")),
                    ("Clean", "ResNet Model", tf.keras.models.load_model("../Data/Model/Clean_ResNet.h5"))]

DataDescriptions = [("Adversarial", Adversarial_X_Valid, Adversarial_y_Valid)]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# Results on Adversarial Validation Dataset

# %%
Evaluate_Models_Datasets(ModelDescriptions, DataDescriptions, "Models_CW_Accuracy.png", (0,0.6), ValidBatchSize=32)
# Out:
# Evaluating Models on Datasets
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Attack Success of Models
# Success of Adversarial Attack on Models

# %% [markdown]
# ### Comparison on PGD-Attack

# %% [markdown]
# Adversarial Data

# %%
# Loading Validation Data
f = open("../Data/PGD-Attack/Adversarial-Data-Valid/Adversarial_X_Valid.pkl","rb")
Adversarial_X_Valid = pickle.load(f)

f = open("../Data/PGD-Attack/Adversarial-Data-Valid/Adversarial_y_Valid.pkl","rb")
Adversarial_y_Valid = pickle.load(f)

# %% [markdown]
# Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5")),
                    ("Clean", "Robust CNN Model", tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")),
                    ("Clean", "CLDNN Model", tf.keras.models.load_model("../Data/Model/Clean_CLDNN.h5")),
                    ("Clean", "ResNet Model", tf.keras.models.load_model("../Data/Model/Clean_ResNet.h5"))]

BaseModel = tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")

DataDescriptions = [("Adversarial", Adversarial_X_Valid, Adversarial_y_Valid)]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# Accuracy

# %%
AttackSuccess(ModelDescriptions, DataDescriptions, "AttackSuccess_PGD.png", (0.8,1), ValidBatchSize=32)
# Out:
# Evaluating Models on Datasets
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Comparison on CW-Attack

# %% [markdown]
# Adversarial Data

# %%
# Loading Validation Data
f = open("../Data/CW-Attack/Adversarial-Data-Valid/Adversarial_X_Valid.pkl","rb")
Adversarial_X_Valid = pickle.load(f)

f = open("../Data/CW-Attack/Adversarial-Data-Valid/Adversarial_y_Valid.pkl","rb")
Adversarial_y_Valid = pickle.load(f)

# %% [markdown]
# Models

# %%
ModelDescriptions = [("Clean", "AutoML ResNet Model", tf.keras.models.load_model("../Models/Clean_ResNet.h5")),
                    ("Clean", "AutoML CLDNN Model", tf.keras.models.load_model("../Models/Clean_CLDNN.h5")),
                    ("Clean", "AutoML CNN Model", tf.keras.models.load_model("../Models/Clean_CNN.h5")),
                    ("Clean", "AutoML RNN Model", tf.keras.models.load_model("../Models/Clean_RNN.h5")),
                    ("Clean", "Robust CNN Model", tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")),
                    ("Clean", "CLDNN Model", tf.keras.models.load_model("../Data/Model/Clean_CLDNN.h5")),
                    ("Clean", "ResNet Model", tf.keras.models.load_model("../Data/Model/Clean_ResNet.h5"))]

BaseModel = tf.keras.models.load_model("../Data/Model/Clean_Robust_CNN.h5")

DataDescriptions = [("Adversarial", Adversarial_X_Valid, Adversarial_y_Valid)]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# Accuracy

# %%
AttackSuccess(ModelDescriptions, DataDescriptions, "AttackSuccess_CW.png", (0.45,1), ValidBatchSize=32)
# Out:
# Evaluating Models on Datasets
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
